# %% [markdown]
# ### Imports

# %%
import pandas as pd
import sys

import warnings
warnings.filterwarnings('ignore')

sys.path.append('scripts/make_plots/')

# %% [markdown]
# ## Exploring the degree of order and disorder in reference databases using HCA score

# %%
from hcascore_distributions import *

# %%
table = 'tables/datasetS3.csv'
df_a=pd.read_csv(table,sep=";")
all_fold(df_a)

# %% [markdown]
# ## Leveraging AlphaFold2 predictions with pyHCA package

# %%
sys.path.append('scripts/AF2_database/')
from mk_barplot import *
# os.system("gunzip tables/datasetS4.csv.gz")

# %%
from_table_to_barplots("tables/datasetS4.csv","all proteomes")

# %%
from_table_to_barplots("tables/datasetS4.csv","METJA")

# %%
from_table_to_barplots("tables/datasetS4.csv","MYCTU")

# %%
from_table_to_barplots("tables/datasetS4.csv","HUMAN")

# %%
from_table_to_barplots("tables/datasetS4.csv","ORYSJ")

# %%
from_table_to_barplots("tables/datasetS4.csv","PLAF7")
